# %%
#Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Load the data
df = pd.read_csv('DATA.csv') 
df.head()
# Out:
#    Age  Gender MonthlyIncome              Department  NumCompaniesWorked  \
# 0   31  Female           low  Research & Development                   1
# 1   32    Male           low  Research & Development                   0
# 2   34  Female        medium  Research & Development                   3
# 3   49    Male          high  Research & Development                   4
# 4   27    Male        medium  Research & Development                   1
#
#   Over18  workingfromhome     BusinessTravel  DistanceFromHome  StandardHours  \
# 0      Y                0      Travel_Rarely                 2             40
# 1      Y                0  Travel_Frequently                 2             40
# 2      Y                1      Travel_Rarely                 8             40
# 3      Y                0      Travel_Rarely                 1             40
# 4      Y                0      Travel_Rarely                19             40
#
#    JobSatisfaction  complaintfiled complaintresolved  complaintyears  \
# 0                4               1                 Y             0.0
# 1                4               0               NaN             NaN
# 2                1               0               NaN             NaN
# 3                3               0               NaN             NaN
# 4                1               0               NaN             NaN
#
#    PercentSalaryHike  PerformanceRating  TotalWorkingYears  YearsAtCompany  \
# 0                 11                  1                  1               1
# 1                 13                  2                  8               7
# 2                 14                  3                  7               0
# 3                 14                  3                 23               8
# 4                 11                  1                  7               7
#
#    YearsSinceLastPromotion Left
# 0                        0   No
# 1                        3   No
# 2                        0   No
# 3                        0   No
# 4                        0   No

# %%
df.shape
# Out:
# (1474, 20)

# %%
df.dtypes
# Out:
# Age                          int64
# Gender                      object
# MonthlyIncome               object
# Department                  object
# NumCompaniesWorked           int64
# Over18                      object
# workingfromhome              int64
# BusinessTravel              object
# DistanceFromHome             int64
# StandardHours                int64
# JobSatisfaction              int64
# complaintfiled               int64
# complaintresolved           object
# complaintyears             float64
# PercentSalaryHike            int64
# PerformanceRating            int64
# TotalWorkingYears            int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# Left                        object
# dtype: object

# %%
#Count the empty (NaN, NAN, na) values in each column
df.isna().sum()
# Out:
# Age                           0
# Gender                        0
# MonthlyIncome                 0
# Department                    0
# NumCompaniesWorked            0
# Over18                        0
# workingfromhome               0
# BusinessTravel                0
# DistanceFromHome              0
# StandardHours                 0
# JobSatisfaction               0
# complaintfiled                0
# complaintresolved          1180
# complaintyears             1211
# PercentSalaryHike             0
# PerformanceRating             0
# TotalWorkingYears             0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# Left                          0
# dtype: int64

# %%
df.describe()
# Out:
#                Age  NumCompaniesWorked  workingfromhome  DistanceFromHome  \
# count  1474.000000         1474.000000      1474.000000       1474.000000
# mean     36.945047            2.695387         0.456581          9.200136
# std       9.153312            2.501083         0.498280          8.115843
# min      18.000000            0.000000         0.000000          1.000000
# 25%      30.000000            1.000000         0.000000          2.000000
# 50%      36.000000            2.000000         0.000000          7.000000
# 75%      43.000000            4.000000         1.000000         14.000000
# max      60.000000            9.000000         1.000000         29.000000
#
#        StandardHours  JobSatisfaction  complaintfiled  complaintyears  \
# count         1474.0      1474.000000     1474.000000      263.000000
# mean            40.0         2.731343        0.199457        1.106464
# std              0.0         1.102861        0.399728        1.020812
# min             40.0         1.000000        0.000000        0.000000
# 25%             40.0         2.000000        0.000000        0.000000
# 50%             40.0         3.000000        0.000000        1.000000
# 75%             40.0         4.000000        0.000000        2.000000
# max             40.0         4.000000        1.000000        4.000000
#
#        PercentSalaryHike  PerformanceRating  TotalWorkingYears  \
# count        1474.000000        1474.000000        1474.000000
# mean           15.204885           2.871099          11.291045
# std             3.656512           1.399134           7.785923
# min            11.000000           1.000000           0.000000
# 25%            12.000000           2.000000           6.000000
# 50%            14.000000           3.000000          10.000000
# 75%            18.000000           4.000000          15.000000
# max            25.000000           5.000000          40.000000
#
#        YearsAtCompany  YearsSinceLastPromotion
# count     1474.000000              1474.000000
# mean         7.008820                 2.190638
# std          6.120918                 3.221768
# min          0.000000                 0.000000
# 25%          3.000000                 0.000000
# 50%          5.000000                 1.000000
# 75%          9.000000                 3.000000
# max         40.000000                15.000000

# %%
df['Left'].value_counts()
# Out:
# No     1233
# Yes     241
# Name: Left, dtype: int64

# %%
#Drop columns useful column

#Over 18
df = df.drop('Over18', axis = 1)
#StandardHours
df = df.drop('StandardHours', axis = 1)
#complaintresolved 
df = df.drop('complaintresolved', axis = 1)
#complaintyears
df = df.drop('complaintyears', axis = 1)

# %%
df.isna().sum()
# Out:
# Age                        0
# Gender                     0
# MonthlyIncome              0
# Department                 0
# NumCompaniesWorked         0
# workingfromhome            0
# BusinessTravel             0
# DistanceFromHome           0
# JobSatisfaction            0
# complaintfiled             0
# PercentSalaryHike          0
# PerformanceRating          0
# TotalWorkingYears          0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# Left                       0
# dtype: int64

# %%
df.shape
# Out:
# (1474, 16)

# %%
df.corr()
# Out:
#                               Age  NumCompaniesWorked  workingfromhome  \
# Age                      1.000000            0.302426        -0.074278
# NumCompaniesWorked       0.302426            1.000000        -0.035951
# workingfromhome         -0.074278           -0.035951         1.000000
# DistanceFromHome        -0.005417           -0.032112         0.044875
# JobSatisfaction         -0.003346           -0.054547        -0.038537
# complaintfiled           0.017285           -0.000980        -0.014434
# PercentSalaryHike        0.002710           -0.010616         0.019045
# PerformanceRating        0.017364           -0.010258         0.014364
# TotalWorkingYears        0.681121            0.240854        -0.044425
# YearsAtCompany           0.310197           -0.119292        -0.021132
# YearsSinceLastPromotion  0.215280           -0.038031         0.007063
#
#                          DistanceFromHome  JobSatisfaction  complaintfiled  \
# Age                             -0.005417        -0.003346        0.017285
# NumCompaniesWorked              -0.032112        -0.054547       -0.000980
# workingfromhome                  0.044875        -0.038537       -0.014434
# DistanceFromHome                 1.000000        -0.001953       -0.019847
# JobSatisfaction                 -0.001953         1.000000        0.006137
# complaintfiled                  -0.019847         0.006137        1.000000
# PercentSalaryHike                0.039590         0.018878        0.022650
# PerformanceRating                0.030732         0.024618        0.004730
# TotalWorkingYears                0.002483        -0.018559        0.019072
# YearsAtCompany                   0.009230        -0.004174        0.013154
# YearsSinceLastPromotion          0.011392        -0.017102        0.002611
#
#                          PercentSalaryHike  PerformanceRating  \
# Age                               0.002710           0.017364
# NumCompaniesWorked               -0.010616          -0.010258
# workingfromhome                   0.019045           0.014364
# DistanceFromHome                  0.039590           0.030732
# JobSatisfaction                   0.018878           0.024618
# complaintfiled                    0.022650           0.004730
# PercentSalaryHike                 1.000000           0.938976
# PerformanceRating                 0.938976           1.000000
# TotalWorkingYears                -0.021006          -0.021731
# YearsAtCompany                   -0.035965          -0.042119
# YearsSinceLastPromotion          -0.021932          -0.041082
#
#                          TotalWorkingYears  YearsAtCompany  \
# Age                               0.681121        0.310197
# NumCompaniesWorked                0.240854       -0.119292
# workingfromhome                  -0.044425       -0.021132
# DistanceFromHome                  0.002483        0.009230
# JobSatisfaction                  -0.018559       -0.004174
# complaintfiled                    0.019072        0.013154
# PercentSalaryHike                -0.021006       -0.035965
# PerformanceRating                -0.021731       -0.042119
# TotalWorkingYears                 1.000000        0.625669
# YearsAtCompany                    0.625669        1.000000
# YearsSinceLastPromotion           0.403341        0.617896
#
#                          YearsSinceLastPromotion
# Age                                     0.215280
# NumCompaniesWorked                     -0.038031
# workingfromhome                         0.007063
# DistanceFromHome                        0.011392
# JobSatisfaction                        -0.017102
# complaintfiled                          0.002611
# PercentSalaryHike                      -0.021932
# PerformanceRating                      -0.041082
# TotalWorkingYears                       0.403341
# YearsAtCompany                          0.617896
# YearsSinceLastPromotion                 1.000000

# %%
import matplotlib.pyplot as plt

# %%
#Visualize the correlation
plt.figure(figsize=(11,11))  
sns.heatmap(df.corr(), annot=True, fmt='.0%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Transform non-numeric columns to numerical columns.

# %%
from sklearn.preprocessing import LabelEncoder

for column in df.columns:
        if df[column].dtype == np.number:
            continue
        df[column] = LabelEncoder().fit_transform(df[column])
# Out:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# <ipython-input-14-4e45a66a5583>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:

# %%
df
# Out:
#       Age  Gender  MonthlyIncome  Department  NumCompaniesWorked  \
# 0      13       0              1           1                   1
# 1      14       1              1           1                   0
# 2      16       0              2           1                   3
# 3      31       1              0           1                   4
# 4       9       1              2           1                   1
# ...   ...     ...            ...         ...                 ...
# 1469   19       1              1           1                   1
# 1470   18       0              1           1                   9
# 1471   19       0              2           1                   2
# 1472    8       1              1           1                   1
# 1473   16       1              2           2                   1
#
#       workingfromhome  BusinessTravel  DistanceFromHome  JobSatisfaction  \
# 0                   0               2                 1                3
# 1                   0               1                 1                3
# 2                   1               2                 7                0
# 3                   0               2                 0                2
# 4                   0               2                18                0
# ...               ...             ...               ...              ...
# 1469                1               1                 8                3
# 1470                0               2                 4                0
# 1471                0               2                 0                0
# 1472                1               2                24                2
# 1473                1               2                20                3
#
#       complaintfiled  PercentSalaryHike  PerformanceRating  TotalWorkingYears  \
# 0                  1                  0                  0                  1
# 1                  0                  2                  1                  8
# 2                  0                  3                  2                  7
# 3                  0                  3                  2                 23
# 4                  0                  0                  0                  7
# ...              ...                ...                ...                ...
# 1469               0                  1                  1                  4
# 1470               0                  3                  1                  6
# 1471               1                  3                  2                 17
# 1472               0                  1                  0                  1
# 1473               0                  1                  0                 10
#
#       YearsAtCompany  YearsSinceLastPromotion  Left
# 0                  1                        0     0
# 1                  7                        3     0
# 2                  0                        0     0
# 3                  8                        0     0
# 4                  7                        0     0
# ...              ...                      ...   ...
# 1469               4                        1     0
# 1470               1                        0     0
# 1471               3                        0     0
# 1472               1                        0     1
# 1473              10                        5     0
#
# [1474 rows x 16 columns]

# %% [markdown]
# #Split the data into X and Y

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
 from sklearn.ensemble import RandomForestClassifier

# %%
  Forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
  Forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
Forest.score(X_train, Y_train)
# Out:
# 0.9804919423240034

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(Y_test, Forest.predict(X_test))
  
TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]
  
print(cm)
print('Model Testing Accuracy = "{}!"'.format(  (TP + TN) / (TP + TN + FN + FP)))
print()
# Out:
# [[239   6]
#  [ 45   5]]
# Model Testing Accuracy = "0.8271186440677966!"

# %%
importances = pd.DataFrame({'feature':df.iloc[:, 0:-1].columns,'importance':np.round(Forest.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances
# Out:
#                          importance
# feature
# Age                           0.138
# DistanceFromHome              0.110
# TotalWorkingYears             0.102
# YearsAtCompany                0.098
# NumCompaniesWorked            0.082
# PercentSalaryHike             0.081
# YearsSinceLastPromotion       0.074
# JobSatisfaction               0.059
# PerformanceRating             0.057
# Department                    0.050
# BusinessTravel                0.043
# MonthlyIncome                 0.037
# Gender                        0.029
# workingfromhome               0.023
# complaintfiled                0.016

# %%
importances.plot.bar(color='Green')
# Out:
# <AxesSubplot:xlabel='feature'>
